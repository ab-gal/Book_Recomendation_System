# %%
import re
import time
import random
from urllib.parse import urljoin

import requests
import pandas as pd
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r"..\data\clean\books_merged_clean.csv")

# %%
df['language'].value_counts()
# Out:
# language
# english                                         560
# german                                          137
# french                                           62
# spanish                                          40
# italian                                          31
#                                                ...
# english, japanese                                 1
# multiple languages, german, chinese, english      1
# french, english, german, italian, portuguese      1
# unknown                                           1
# latin                                             1
# Name: count, Length: 64, dtype: int64
