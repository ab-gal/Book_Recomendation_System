# %%
pip install streamlit
# Out:
# Note: you may need to restart the kernel to use updated packages.
# C:\Users\ghaza\Desktop\Ironhack_Data_Analytics\week_10\project\Book_Recomendation_System\.venv\Scripts\python.exe: No module named pip
